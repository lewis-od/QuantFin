# %% [markdown]
# # Random Walk
#
# Plots 2 different types of random walk - geometric Brownian and mean reverting.

# %%
# %matplotlib inline
from quantfin.random_walk import geometric_brownian, mean_reversion
import matplotlib.pyplot as plt

# %%
x1 = geometric_brownian(500, 100, 0.0, 0.05)
x2 = geometric_brownian(500, 100, 0.0, 0.05)
x3 = geometric_brownian(500, 100, 0.0, 0.05)
x4 = geometric_brownian(500, 100, 0.0, 0.05)

y_min = 0.0
y_max = max(x1.max(), x2.max(), x3.max(), x4.max())

plt.plot(x1);
plt.plot(x2);
plt.plot(x3);
plt.plot(x4);

plt.ylim((y_min, y_max));
plt.xlim((0, 500));

# %%
x1 = mean_reversion(500, 1.0, 1.0, 1.0)
x2 = mean_reversion(500, 1.0, 1.0, 0.1)
x3 = mean_reversion(500, 1.0, 1.0, 0.01)

y_max = max(x1.max(), x2.max(), x3.max())
y_min = min(x1.min(), x2.min(), x3.min())

plt.plot(x1);
plt.plot(x2);
plt.plot(x3);

plt.xlim((0, 500));
plt.ylim((y_min, y_max));
plt.legend(["a = 1.0", "a = 0.1", "a = 0.01"]);
